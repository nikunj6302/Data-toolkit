# %% [markdown]
# #Data toolkit assingment

# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python?
#  - Numpy is a libraty of a python. It has consist of numarical and advance methemetical function. That is also a reason to widely use it.
#
# 2. How does broadcasting work in NumPy?
#   - while operating any number in matrix it will operate row wise first than it will operate together.
#
# 3. What is a Pandas DataFrame?
#  - Data frame is combination of rows and collomns. it is basicaly a table of data.
#
# 4. Explain the use of the groupby() method in Pandas?
#    -The groupby() method in Pandas is used to split a DataFrame into groups based on one or more criteria, typically the unique values in one or more columns.
#
# 5. Why is Seaborn preferred for statistical visualizations?
#   - Becasue it providing a high-level interface for drawing attractive and informative statistical graphics.
#
# 6. What are the differences between NumPy arrays and Python lists?
#   -  Numpy arrays stores homogenous data while list stores hetrogeneus data.
#
# 7.  What is a heatmap, and when should it be used?
#   - heatmap is a visualization technique that uses color to represent data values, with darker colors indicating higher values and lighter colors indicating lower values
#
# 8.  What does the term “vectorized operation” mean in NumPy?
#   - It is basicaly matric operationa instead of operating each value it will operate row to collumn and then sum of the resultant value.
#
# 9. How does Matplotlib differ from Plotly?
#   - Matplotlib can fine-tune just about any aspect of the figure—fonts, margins, axis scales, etc. Plotly's real strength lies in interactivity and web-based visuals.
#
# 10. What is the significance of hierarchical indexing in Pandas?
#   - Hierarchical indexing, also known as MultiIndex, in Pandas is a powerful feature that allows for multiple levels of indexing on an axis (rows or columns) of a Series or DataFrame.
#
# 11. What is the role of Seaborn’s pairplot() function?
#   - Seaborn's pairplot() function serves as a powerful tool for visualizing pairwise relationships between multiple variables within a dataset. Its primary role is to generate a grid of plots, where each numerical variable in the dataset is represented on both the x and y axes across the grid.
#
# 12. What is the purpose of the describe() function in Pandas?
#   - The describe() function in Pandas is used to generate descriptive statistics
#
# 13. Why is handling missing data important in Pandas?
#   - Handling missing data in Pandas is crucial for several reasons, primarily impacting the accuracy and reliability of data analysis and machine learning models
#
# 14. What are the benefits of using Plotly for data visualization?
#    -Plotly offers a wide range of chart types, from simple line charts to complex 3D plots, enabling diverse and comprehensive data visualizations
#
# 15.  How does NumPy handle multidimensional arrays?
#   - NumPy handles multidimensional arrays through its core object, the ndarray. This object allows for efficient storage and manipulation of homogeneous data (all elements of the same type) across multiple dimensions.
#
# 16. What is the role of Bokeh in data visualization?
#   - Bokeh is a Python library that plays a crucial role in data visualization by enabling the creation of interactive and dynamic charts and plots
#
# 17. Explain the difference between apply() and map() in Pandas.
#   - Use map() when we need to perform a simple, element-wise substitution or transformation on a Pandas Series. Use apply() when we need to apply a more complex function element-wise to a Series, or when we need to apply a function along an axis (row-wise or column-wise) of a DataFrame.
#
# 18.  What are some advanced features of NumPy?
#    - Broadcasting, Linear Algebra, Random Number Generation, Reshaping, Vectorization these are few example of advance features of NumPy.
#
# 19.  How does Pandas simplify time series analysis?
#   - Pandas provides specialized datetime objects and functions that make it easy to work with dates and times. It can convert various date representations into a standardized format, allowing for straightforward manipulation and analysis of time-based data.
#
# 20. What is the role of a pivot table in Pandas?
#   - The pivot() function is an incredibly useful tool for transforming and summarizing data. It allows you to restructure a DataFrame by turning rows into columns and columns into rows based on a specified index column, a specified columns column, and a specified values column.
#
# 21. Why is NumPy’s array slicing faster than Python’s list slicing?
#   - NumPy array slicing is generally faster than Python list slicing due to several fundamental differences in their underlying implementations and memory management
#
# 22. What are some common use cases for Seaborn?
#   - Seaborn is a Python data visualization library built on Matplotlib, offering a high-level interface for creating informative and attractive statistical graphics.

# %% [markdown]
# #Practical Assignment

# %%
#Ans. 1
import numpy as np

lst1 = [1,2,3,4,5]
lst2 = [6,7,8,9,0]

arr = np.array([lst1,lst2])

arr[0]+arr[1]
# Out:
# array([ 7,  9, 11, 13,  5])

# %%
#Ans. 2
import pandas as pd

df = pd.read_csv('Project COC.csv')
print(df)

mn = np.mean(df['Hitpoints'])
print(f"\n \n This is the mean of coloum Hitpoint in data frame: {mn}")
# Out:
#       Name of troop  Level  Housing Space  Hitpoints  Damage per second  \
# 0         Barbarian      8              1        205                 34
# 1            Archer      6              1         44                 22
# 2             Giant      6              5       1100                 43
# 3            Goblin      8              1        105                 52
# 4      Wall Breaker      4              2         35                 20
# 5            Ballon      6              5        545                162
# 6            Wizard      6              4        180                185
# 7            Dragon      7             20       3900                310
# 8         P.E.K.K.A      4             25       4500                360
# 9       Baby Dragon      1             10       1200                 75
# 10            Miner      2              6        610                 88
# 11   Electro Dragon      4             30       4500                330
# ...

# %%
#Ans. 3
import matplotlib.pyplot as plt

plt.scatter(df['Housing Space'],df['Hitpoints'])
plt.show()

# %%
#Ans. 4
import seaborn as sns

# data = df['Level','Damage per second']

data = pd.read_csv('Project COC.csv', usecols=['Level','Damage per second','Hitpoints', 'Housing Space'])


plt.figure(figsize=(10, 10))
sns.heatmap(data)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Ans. 5
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=df['Level'], y=df['Damage per second']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Ans. 6
inx = []

for i in range(1,25):
  inx.append(i)

inx

df.insert(0,"index",inx)

df
# Out:
#     index    Name of troop  Level  Housing Space  Hitpoints  \
# 0       1        Barbarian      8              1        205
# 1       2           Archer      6              1         44
# 2       3            Giant      6              5       1100
# 3       4           Goblin      8              1        105
# 4       5     Wall Breaker      4              2         35
# 5       6           Ballon      6              5        545
# 6       7           Wizard      6              4        180
# 7       8           Dragon      7             20       3900
# 8       9        P.E.K.K.A      4             25       4500
# 9      10      Baby Dragon      1             10       1200
# 10     11            Miner      2              6        610
# 11     12   Electro Dragon      4             30       4500
# 12     13             Yeti      4             18       3500
# 13     14           Minion      3              2         68
# 14     15        Hog Rider     10              5        970
# ...

# %%
#Ans. 7
mat1 = np.random.randint(1,10, (3,3))
mat2 = np.random.randint(1,10, (3,3))

print(mat1)
print(mat2)

print(mat1*mat2)
# Out:
# [[8 4 1]
#  [1 5 4]
#  [7 3 9]]
# [[4 2 6]
#  [5 7 6]
#  [9 1 7]]
# [[32  8  6]
#  [ 5 35 24]
#  [63  3 63]]

# %%
#Ans. 8

df_sort = df.sort_values(by='Housing Space')
x = df_sort['Housing Space']
y1 = df_sort['Damage per second']
y2 = df_sort['Hitpoints']

plt.plot(x,y1, color='red', label='Damage per second', marker="o")
plt.plot(x,y2, color='green', label='Hitpoints', marker="o")
plt.show()

# %%
#Ans. 9
df[df['Damage per Space']>30]
# Out:
#     index    Name of troop  Level  Housing Space  Hitpoints  \
# 0       1        Barbarian      8              1        205
# 3       4           Goblin      8              1        105
# 5       6           Ballon      6              5        545
# 6       7           Wizard      6              4        180
# 14     15        Hog Rider     10              5        970
# 19     20  Super Barbarian      8              5       1000
# 20     21    Sneaky Goblin      7              3        270
#
#     Damage per second  Damage destroyed  Movement speed  \
# 0                  34                 0              16
# 3                  52                 0              32
# 5                 162               162              10
# 6                 185                 0              16
# 14                176                 0              24
# 19                180                 0              20
# 20                155                 0              32
#
# ...

# %%
#Ans. 10
import seaborn as sns


sns.histplot(data=df, x='Movement speed', bins=30, kde=True)
# Out:
# <Axes: xlabel='Movement speed', ylabel='Count'>

# %%
#Ans. 11

mat1 = np.random.randint(1,10, (3,3))
mat2 = np.random.randint(1,10, (3,3))

print(mat1)
print(mat2)

print(mat1@mat2)
# Out:
# [[6 4 4]
#  [5 2 9]
#  [8 4 9]]
# [[3 9 9]
#  [8 3 1]
#  [7 8 4]]
# [[ 78  98  74]
#  [ 94 123  83]
#  [119 156 112]]

# %%
#Ans. 12
import pandas as pd

df = pd.read_csv('Project COC.csv')
df.head(5)
# Out:
#   Name of troop  Level  Housing Space  Hitpoints  Damage per second  \
# 0     Barbarian      8              1        205                 34
# 1        Archer      6              1         44                 22
# 2         Giant      6              5       1100                 43
# 3        Goblin      8              1        105                 52
# 4  Wall Breaker      4              2         35                 20
#
#    Damage destroyed  Movement speed                 Speciality  \
# 0                 0              16                        NaN
# 1                 0              24                        NaN
# 2                 0              12  Favorite Target Defecnses
# 3                 0              32  Favorite Target Resources
# 4                16              24      Favorite Target Walls
#
#    Hitpoint per Space  Damage per Space  D-damage per space
# 0               205.0              34.0                 0.0
# ...

# %%
#Ans. 13.

import plotly.express as px

x = [1,2,3,4,5]
y = [2,3,5,6,8]
z = [3,6,9,5,10]

fig = px.scatter_3d(x=x, y=y, z=z)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
